# %% [markdown]
# # Intro to Python Workshop Final Assignment
#
# Welcome to this workshop's final assignment, due ***July 3rd at 11:59 PM***. This assignment is worth 55 points in total, and in order to pass, you'll need to score at least 37 points. It is highly recommended that you attempt to solve these problems during the days that we are hosting the workshops so that in case you have any concerns, we can address them live. While this assignment isn't mandatory, successfully completing it will earn you a credential.
#
# For each question, you will need to provide the code you wrote to solve the question as well as the output it gave you; to do this, you may place your answers in a `.py` script, using comments to indicate the questions you are answering. Alternatively, you may do this in a Word document by copy-pasting text/screenshots or downloading this Jupyter/Python notebook and writing in your code and output. If you want any help setting up a Jupyter notebook to use for this assignment, reach out to us and we can help you. Email your final submission to **laze@yorku.ca** with subject line "Python Workshop Submission". Good luck!
#
# 1. Create the following variables and assign values to each one:
# - name (string type)
# - birth year (integer type)
# - hypertension status (boolean type)
# - blood sugar level (float type)
#
#     Print the type of each variable afterwards to ensure their type matches the listed specified types. (4 points)
#
# 2. Print statements that include the following data, using the variables you created in question 1: the patient's name, birthyear, as well as whether they have hypertension. Make sure that the all sentences in your output are meaningful and can be understood by a layman with no additional explanation. (2 points)
#
# 3. Create a list named "mistakes" with the following inconsistent gender labels stored in them: " male ", "ma1e", and "mAle". Once you've created the list named "mistakes", append a new string named "m ale" to it. Print the first item, the last item, and both of the middle items from the "mistakes" list. Clean this list up using string methods such that all entries now read "male" and print the corrections. (3 points)
#
# 4. Create a tuple including your last name, birth year, and whether you have hypertension; make sure each of your values match the format of the variables you created in question 1. Unpack the tuple and print each value on a new line. Why might tuples be used for storing patient records? (2 points)
#
# 5. Create an age variable and set it to 49 years old and create a race variable and set it to 'Hispanic'. Write a boolean expression that flags increased stroke risk, store this risk assessment in a variable named "increased_risk", and print the risk status in a statement that's understandable for laymen.
#
#     Reminder: Patients are at higher risk of stroke if they are past the age of 55 and/or Hispanic. (3 points)
#
# 6. Let's expand on risk status using the same values for age and hypertension as the previous question. With the same variables for age and hypertension status, write conditional statements such that a patient who is over 55 years old and is Hispanic has a "High" stroke risk, a patient who is only either over 55 years old or is Hispanic has a "Moderate" stroke risk, and a patient who is 65 or younger and is not Hispanic has a "Low" stroke risk. Store the risk assessment in a variable named "risk" and print the result. (4 points)
#
# 7. Create a patient list with the following information stored:
# - Patient 1: Johnny Appleseed and has hypertension
# - Patient 2: Jane Doe and has hypertension
# - Patient 3: Annie Oakley and does not have hypertension
# - Patient 4: Tom Sawyer and does not have hypertension
#
#     Using a for loop, print out the name of each patient who has hypertension and print the number of patients in this list who suffer from hypertension. (5 points)
#
# 8. Import the numpy, pandas, the pyplot module from matplotlib, and statsmodels according to standard convention. Once that's done, import the stroke dataset under the name "stroke_data". (2 points)
#
# 9. Create a function to determine the median glucose level amongst all patients. (2 points)
#
# 10. Explore the stroke dataset. Compare the entries for the first 10 patients who have had a stroke to the first 10 entries of patients who haven't had a stroke. Describe the different types of variables in the data and how many there are of each type. Compile descriptive statistics for any two of the three ratio variables in this datatset in a single table. Find out which variable contains missing data points and how many missing values there were, then drop all rows containing missing values. Confirm how many total entries there are after removing all rows with missing values. Create a BMI histogram with 6 red bars. Create a scatterplot of average glucose level by BMI as well. For increased discernment between data points, set the transparency of your points to 0.5 for your scatterplot. (14 points)
#
# 11. Calculate the median glucose level for all participants in the dataset using your previously defined function. Conduct a two-sided Welch's t-test to see if there is a significant difference in average glucose levels between those who have hypertension and those who do not; report the findings of this t-test. (Don't worry about assumption testing here.) Print the median glucose level by whether the patient suffered a stroke. (4 points)
#
# 12. Generate a new data frame that includes synthetic data for 500 participants. Make sure to set your seed to 37 for reproducibility purposes. Generate the gender for all participants randomly. (4 points)
#     To create the other variables, copy-paste the following code into your data frame:
#
#         "age": np.random.randint(18, 90, size=n_new),
#         "hypertension": np.random.choice([0, 1], size=n_new, p=[0.85, 0.15]),
#         "heart_disease": np.random.choice([0, 1], size=n_new, p=[0.9, 0.1]),
#         "ever_married": np.random.choice(["Yes", "No"], size=n_new),
#         "work_type": np.random.choice(
#                 ["Private", "Self-employed", "Govt_job", "children", "Never_worked"], size=n_new
#             ),
#         "Residence_type": np.random.choice(["Urban", "Rural"], size=n_new),
#         "avg_glucose_level": np.random.normal(loc=100, scale=30, size=n_new),
#         "bmi": np.random.normal(loc=28, scale=7, size=n_new),
#         "smoking_status": np.random.choice(
#                 ["formerly smoked", "never smoked", "smokes", "Unknown"], size=n_new
#             )
#
#     Once the synthetic dataframe has been created, run the following code afterwards to make the data more realistic:
#
#         synthetic_data["avg_glucose_level"] = synthetic_data["avg_glucose_level"].clip(lower=50, upper=300)
#         synthetic_data["bmi"] = synthetic_data["bmi"].clip(lower=10, upper=60)
#
#         base_risk = 0.02
#
#         risk_score = (
#             base_risk
#             + 0.003 * synthetic_data["age"]
#             + 0.15 * synthetic_data["hypertension"]
#             + 0.20 * synthetic_data["heart_disease"]
#         )
#
#         prob_stroke = 1 / (1 + np.exp(-risk_score))
#
#         synthetic_data["stroke"] = np.random.binomial(1, prob_stroke)
#
# 13. Add your randomly generated data to the existing stroke dataset and save it as a separate file named "expanded_stroke_dataset.csv". (1 point)
#
# 14. Create a correlation matrix showing the relationship between age, BMI, and average glucose level. Generate a statistical model regressing the occurence of stroke on age, hypertension occurence, and heart disease occurence. Generate a second statistical model regressing stroke occurence on the same 3 main effects as well as interaction effects between all of the variables. Compare the two models and determine whether the second model that includes the interaction effects explains significantly more variation in stroke occurence than the main-effects only model. (5 points)
