# %% [markdown]
# # Intro to Python Workshop Final Assignment
#
# Welcome to this workshop's final assignment, due ***July 3rd at 11:59 PM***. This assignment is worth 53 points in total, and in order to pass, you'll need to score at least 37 points. It is high[...]
# For each question, you will need to provide the code you wrote to solve the question as well as the output it gave you; to do this, you may place your answers in a `.py` script, using comments to[...]
# 1. Create the following variables and assign values to each one:
# - name (string type)
# - birth year (integer type)
# - hypertension status (boolean type)
# - blood sugar level (float type)
#
#     Print the type of each variable afterwards to ensure their type matches the listed specified types. (4 points)
#
# 2. Print statements that include the following data, using the variables you created in question 1: the patient's name, birthyear, as well as whether they have hypertension. Make sure that the al[...]
#
# 3. Create a list named `mistakes` with the following inconsistent gender labels stored in them: " male ", "ma1e", and "mAle". Once you've created the list named `mistakes`, append a new st[...]
#
# 4. Create a tuple including your last name, birth year, and whether you have hypertension; make sure each of your values match the format of the variables you created in question 1. Unpack the tu[...]
#
# 5. Mario Mario is a new 49 year old Hispanic patient. To store his information, create a variable `race` and set it to 'Hispanic'. Write a boolean expression that flags increased stroke risk, sto[...]
#
#     Reminder: Patients are at higher risk of stroke if they are past the age of 55 and/or Hispanic. (3 points)
#
# 6. Let's expand on risk status using the same values for age and hypertension as the previous question. With the same variables for age and hypertension status, write conditional statements s[...]
#
# 7. Create a list `patients` with the following information stored:
# - Patient 1: Johnny Appleseed and has hypertension
# - Patient 2: Jane Doe and has hypertension
# - Patient 3: Annie Oakley and does not have hypertension
# - Patient 4: Tom Sawyer and does not have hypertension
#
#     Using a for loop, print out the name of each patient who has hypertension and print the number of patients in this list who suffer from hypertension. Then, create a two column pandas datafram[...]
#
# 8. Import the numpy, pandas, the pyplot module from matplotlib, and statsmodels according to standard convention. Download **stroke-data.csv** from the workshop GitHub. Once that's done, import t[...]
#
# 9. Create a function to determine the median glucose level amongst all patients. (2 points)
#
# 10. Explore the stroke dataset. Get the entries for the first 10 patients who have had a stroke as well as the first 10 entries of patients who haven't had a stroke. Find out the different types [...]
#
# 11. Calculate the median glucose level for all participants in the dataset using your previously defined function. Conduct a two-sided Welch's t-test to see if there is a significant difference i[...]
#
# 12. Generate a statistical model regressing the occurence of stroke on age, hypertension occurence, and heart disease occurence. Generate a second statistical model regressing stroke occurenc[...]
